# %% [markdown]
# # Exploratory Data Analysis for STRIP AI
#
# This notebook explores the Mayo Clinic STRIP dataset for stroke blood clot classification.

# %%
import sys
sys.path.append('..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %matplotlib inline
sns.set_style('whitegrid')

# %% [markdown]
# ## 1. Dataset Overview
#
# First, let's examine the structure and composition of our dataset.

# %%
# Set data directory
data_dir = Path('../data/raw')

# TODO: Load and display basic dataset statistics
# - Number of patients per class
# - Number of images per patient
# - Total images per class

# %% [markdown]
# ## 2. Class Distribution

# %%
# TODO: Visualize class distribution
# - Bar plot of CE vs LAA samples
# - Calculate class imbalance ratio

# %% [markdown]
# ## 3. Image Properties

# %%
# TODO: Analyze image properties
# - Image dimensions distribution
# - Pixel intensity statistics
# - Image format and bit depth

# %% [markdown]
# ## 4. Sample Visualization

# %%
# TODO: Display sample images from each class
# Show 4-6 examples of CE and LAA

# %% [markdown]
# ## 5. Data Quality Checks

# %%
# TODO: Check for data quality issues
# - Missing files
# - Corrupted images
# - Duplicate images
# - Outliers in image properties

# %% [markdown]
# ## 6. Recommendations
#
# Based on the EDA, document recommendations for:
# - Preprocessing steps needed
# - Augmentation strategies
# - Handling class imbalance
# - Train/val/test split strategy
